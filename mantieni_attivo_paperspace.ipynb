# %%
import time

contatore = 0

while True:
    print(contatore)
    contatore += 1
    time.sleep(300)
# Out:
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/enrico/Documenti/Borsa/mantieni_attivo_paperspace.ipynb Cell 1 line 8
#       <a href='vscode-notebook-cell:/home/enrico/Documenti/Borsa/mantieni_attivo_paperspace.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> print(contatore)
#       <a href='vscode-notebook-cell:/home/enrico/Documenti/Borsa/mantieni_attivo_paperspace.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> contatore += 1
# ----> <a href='vscode-notebook-cell:/home/enrico/Documenti/Borsa/mantieni_attivo_paperspace.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> time.sleep(300)
#
# KeyboardInterrupt:
