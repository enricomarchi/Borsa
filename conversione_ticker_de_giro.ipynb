# %%
import pandas as pd
pd.set_option("display.max_columns", None)
elenco_usin = pd.read_excel("DeGiro con formule.xlsx")
elenco_usin.drop(columns=["Ticker/USIN", "Unnamed: 4", "Unnamed: 5"], inplace=True)
elenco_usin.to_parquet("Tickers_De_Giro.parquet")

# %%
elenco_usin
# Out:
#                                             Descrizione Categoria Borsa  \
# 0                                            Guess? Inc         C   NSY
# 1                                     1-800 FLOWERS.COM         C   NDQ
# 2                                      10X Genomics Inc         D   NDQ
# 3                                               111 Inc         D   NDQ
# 4     17 EDUCATION & TECHNOLOGY GROUP INC. - AMERICA...         D   NDQ
# ...                                                 ...       ...   ...
# 5128                                      Volkswagen AG         B   MIL
# 5129                                            WEBUILD         D   MIL
# 5130                                        Webuild SpA         D   MIL
# 5131                                               WIIT         C   MIL
# 5132                                  Zignago Vetro SpA         B   MIL
#
#      Ticker          USIN   Close
# 0       GES  US4016171054   20,03
# ...
